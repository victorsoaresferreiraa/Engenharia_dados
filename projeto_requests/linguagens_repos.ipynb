# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"28927456083","type":"PushEvent","actor":{"id":109895156,"login":"DREWiex","display_login":"DREWiex","gravatar_id":"","url":"https://api.github.com/users/DREWiex","avatar_url":"https://avatars.githubusercontent.com/u/109895156?"},"repo":{"id":632026283,"name":"DREWiex/proyecto-final-spa-BACK","url":"https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK"},"payload":{"repository_id":632026283,"push_id":13565005656,"size":4,"distinct_size":0,"ref":"refs/heads/dev","head":"f2d88d959bece7908f0622c4f6328e11aaa86e36","before":"12c614c342130a750b836144d0bb29931a68bef5","commits":[{"sha":"07544ad6b94ca46f4cf92f89581adca28619c466","author":{"email":"aleon88@gmail.com","name":"DREWiex"},"message":"Probando main","distinct":false,"url":"https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/07544ad6b94ca46f4cf92f89581adca28619c466"},{"sha":"944249b40f7dc3cc8452b3a36460e63c6109d498","author":{"email":"aleon88@gmail.com","name":"DREWiex"},"message":"Limpio main después de error","distinct":false,"url":"https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/944249b40f7dc3cc8452b3a36460e63c6109d498"},{"sha":"e80b3b483a793c39dbd17c3306e3ca985faa0801","author":{"email":"109895156+DREWiex@users.noreply.github.com","name":"DREWiex"},"message":"Delete .DS_Store","distinct":false,"url":"https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/e80b3b483a793c39dbd17c3306e3ca985faa0801"},{"sha":"f2d88d959bece7908f0622c4f6328e11aaa86e36","author":{"email":"109895156+DREWiex@users.noreply.github.com","name":"DREWiex"},"message":"Merge pull request #9 from DREWiex/dev\\n\\nDev","distinct":false,"url":"https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/f2d88d959bece7908f0622c4f6328e11aaa86e36"}]},"public":true,"created_at":"2023-05-08T19:47:03Z"},{"id":"28927456064","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":531115061,"name":"TREEcg/Blue-Bike-to-OSLO","url":"https://api.github.com/repos/TREEcg/Blue-Bike-to-OSLO"},"payload":{"repository_id":531115061,"push_id":13565005652,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"d133794abcee505cb022d455f3ef6d0bb6875363","before":"df596b8adf0abd8e0986601da2ca98a277fa4faa","commits":[{"sha":"d133794abcee505cb022d455f3ef6d0bb6875363","author":{"email":"bot@pieter.pm","name":"Pieter\'s GitHub Actions Bot"},"message":"history: update 2023-05-08T19:46:07","distinct":true,"url":"https://api.github.com/repos/TREEcg/Blue-Bike-to-OSLO/commits/d133794abcee505cb022d455f3ef6d0bb6875363"}]},"public":true,"created_at":"2023-05-08T19:47:03Z","org":{"id":62235665,"login":"TREEcg","gravatar_id":"","url":"https://api.github.com/orgs/TREEcg","avatar_url":"https://avatars.githubusercontent.com/u/62235665?"}},{"id":"28927456068","type":"PushEvent","actor":{"id":32224847,"login":"Pjoao1578","display_login":"Pjoao1578","gravatar_id":"","url":"https://api.github.com/users/Pjoao1578","avatar_url":"https://avatars.githubusercontent.com/u/32224847?"},"repo":{"id":617754251,"name":"Pjoao1578/Upcrypter","url":"https://api.github.com/repos/Pjoao1578/Upcrypter"},"payload":{"repository_id":617754251,"push_id":13565005681,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"aa00e79242884dd7e69eed90ed4da748179b0520","before":"eac494a7bed04874556464cfc2b4af25bbbbeccb","commits":[{"sha":"aa00e79242884dd7e69eed90ed4da748179b0520","author":{"email":"32224847+Pjoao1578@users.noreply.github.com","name":"Pjoao1578"},"message":"Update DLL1","distinct":true,"url":"https://api.github.com/repos/Pjoao1578/Upcrypter/commits/aa00e79242884dd7e69eed90ed4da748179b0520"}]},"public":true,"created_at":"2023-05-08T19:47:03Z"},{"id":"28927456063","type":"PushEvent","actor":{"id":119446310,"login":"i8Raffles","display_login":"i8Raffles","gravatar_id":"","url":"https://api ...

# %%
r.json()
# Out:
# [{'id': '28927456083',
#   'type': 'PushEvent',
#   'actor': {'id': 109895156,
#    'login': 'DREWiex',
#    'display_login': 'DREWiex',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DREWiex',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109895156?'},
#   'repo': {'id': 632026283,
#    'name': 'DREWiex/proyecto-final-spa-BACK',
#    'url': 'https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK'},
#   'payload': {'repository_id': 632026283,
#    'push_id': 13565005656,
#    'size': 4,
#    'distinct_size': 0,
#    'ref': 'refs/heads/dev',
#    'head': 'f2d88d959bece7908f0622c4f6328e11aaa86e36',
#    'before': '12c614c342130a750b836144d0bb29931a68bef5',
#    'commits': [{'sha': '07544ad6b94ca46f4cf92f89581adca28619c466',
#      'author': {'email': 'aleon88@gmail.com', 'name': 'DREWiex'},
#      'message': 'Probando main',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/07544ad6b94ca46f4cf92f89581adca28619c466'},
#     {'sha': '944249b40f7dc3cc8452b3a36460e63c6109d498',
#      'author': {'email': 'aleon88@gmail.com', 'name': 'DREWiex'},
#      'message': 'Limpio main después de error',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/944249b40f7dc3cc8452b3a36460e63c6109d498'},
#     {'sha': 'e80b3b483a793c39dbd17c3306e3ca985faa0801',
#      'author': {'email': '109895156+DREWiex@users.noreply.github.com',
#       'name': 'DREWiex'},
#      'message': 'Delete .DS_Store',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/e80b3b483a793c39dbd17c3306e3ca985faa0801'},
#     {'sha': 'f2d88d959bece7908f0622c4f6328e11aaa86e36',
#      'author': {'email': '109895156+DREWiex@users.noreply.github.com',
#       'name': 'DREWiex'},
#      'message': 'Merge pull request #9 from DREWiex/dev\n\nDev',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DREWiex/proyecto-final-spa-BACK/commits/f2d88d959bece7908f0622c4f6328e11aaa86e36'}]},
#   'public': True,
#   'created_at': '2023-05-08T19:47:03Z'},
#  {'id': '28927456064',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 531115061,
#    'name': 'TREEcg/Blue-Bike-to-OSLO',
#    'url': 'https://api.github.com/repos/TREEcg/Blue-Bike-to-OSLO'},
#   'payload': {'repository_id': 531115061,
#    'push_id': 13565005652,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd133794abcee505cb022d455f3ef6d0bb6875363',
#    'before': 'df596b8adf0abd8e0986601da2ca98a277fa4faa',
#    'commits': [{'sha': 'd133794abcee505cb022d455f3ef6d0bb6875363',
#      'author': {'email': 'bot@pieter.pm',
#       'name': "Pieter's GitHub Actions Bot"},
#      'message': 'history: update 2023-05-08T19:46:07',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TREEcg/Blue-Bike-to-OSLO/commits/d133794abcee505cb022d455f3ef6d0bb6875363'}]},
#   'public': True,
#   'created_at': '2023-05-08T19:47:03Z',
#   'org': {'id': 62235665,
#    'login': 'TREEcg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/TREEcg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62235665?'}},
#  {'id': '28927456068',
#   'type': 'PushEvent',
#   'actor': {'id': 32224847,
#    'login': 'Pjoao1578',
#    'display_login': 'Pjoao1578',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Pjoao1578',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32224847?'},
#   'repo': {'id': 617754251,
#    'name': 'Pjoao1578/Upcrypter',
#    'url': 'https://api.github.com/repos/Pjoao1578/Upcrypter'},
#   'payload': {'repository_id': 617754251,
#    'push_id': 13565005681,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aa00e79242884dd7e69eed90ed4da748179b0520',
#    'before': 'eac494a7bed04874556464cfc2b4af25bbbbeccb',
#    'commits': [{'sha': 'aa00e79242884dd7e69eed90ed4da748179b0520',
#      'author': {'email': '32224847+Pjoao1578@users.noreply.github.com',
#       'name': 'Pjoao1578'},
#      'message': 'Update DLL1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pjoao1578/Upcrypter/commits/aa00e79242884dd7e69eed90ed4da748179b0520'}]},
#   'public': True,
#   'created_at': '2023-05-08T19:47:03Z'},
#  {'id': '28927456063',
#   'type': 'PushEvent',
#   'actor': {'id': 119446310,
#    'login': 'i8Raffles',
#    'display_login': 'i8Raffles',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/i8Raffles',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119446310?'},
#   'repo': {'id': 635016735,
#    'name': 'i8Raffles/lotide',
#    'url': 'https://api.github.com/repos/i8Raffles/lotide'},
#   'payload': {'repository_id': 635016735,
#    'push_id': 13565005689,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd8e556a801fa870650920567823bfbe2b87cffd5',
#    'before': '69978ec219ace5cca6936fc4f3e7dc3ce7cf5665',
#    'commits': [{'sha': 'd8e556a801fa870650920567823bfbe2b87cffd5',
#      'author': {'email': 'muhtasimyasser@gmail.com',
#       'name': 'Md Muhtasim Yasser'},
#      'message': 'added index with all function availability',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/i8Raffles/lotide/commits/d8e556a801fa870650920567823bfbe2b87cffd5'}]},
#   'public': True,
#   'created_at': '2023-05-08T19:47:03Z'},
#  {'id': '28927456039',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 21186993,
#    'login': 'caohai',
#    'display_login': 'caohai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caohai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21186993?'},
#   'repo': {'id': 109200851,
#    'name': 'microsoft/azuredatastudio',
#    'url': 'https://api.github.com/repos/microsoft/azuredatastudio'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/comments/1187827596',
#     'pull_request_review_id': 1417405633,
#     'id': 1187827596,
#     'node_id': 'PRRC_kwDOBoJF085GzM-M',
#     'diff_hunk': '@@ -107,14 +117,16 @@ export class FindObjectDialog extends DialogBase<FindObjectDialogResult> {\n \t\tthis.objectsLoadingComponent.loading = true;\n \t\tthis.findButton.enabled = false;\n \t\ttry {\n-\t\t\tconst results = await this.objectManagementService.search(this.options.contextId, <mssql.ObjectManagement.NodeType[]>this.selectedObjectTypes);\n+\t\t\tconst results = await this.objectManagementService.search(this.options.contextId, this.selectedObjectTypes);',
#     'path': 'extensions/mssql/src/objectManagement/ui/findObjectDialog.ts',
#     'commit_id': 'e15ef0d1056512c959f2241f248c3a845db31a09',
#     'original_commit_id': 'e15ef0d1056512c959f2241f248c3a845db31a09',
#     'user': {'login': 'caohai',
#      'id': 21186993,
#      'node_id': 'MDQ6VXNlcjIxMTg2OTkz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/21186993?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/caohai',
#      'html_url': 'https://github.com/caohai',
#      'followers_url': 'https://api.github.com/users/caohai/followers',
#      'following_url': 'https://api.github.com/users/caohai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/caohai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/caohai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/caohai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/caohai/orgs',
#      'repos_url': 'https://api.github.com/users/caohai/repos',
#      'events_url': 'https://api.github.com/users/caohai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/caohai/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '`this.selectedObjectTypes.map(item => this.getObjectTypeName(item))`?',
#     'created_at': '2023-05-08T19:47:02Z',
#     'updated_at': '2023-05-08T19:47:03Z',
#     'html_url': 'https://github.com/microsoft/azuredatastudio/pull/22936#discussion_r1187827596',
#     'pull_request_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/comments/1187827596'},
#      'html': {'href': 'https://github.com/microsoft/azuredatastudio/pull/22936#discussion_r1187827596'},
#      'pull_request': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936'}},
#     'reactions': {'url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/comments/1187827596/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 120,
#     'original_line': 120,
#     'side': 'RIGHT',
#     'original_position': 112,
#     'position': 112,
#     'subject_type': 'line'},
#    'pull_request': {'url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936',
#     'id': 1335918835,
#     'node_id': 'PR_kwDOBoJF085PoIDz',
#     'html_url': 'https://github.com/microsoft/azuredatastudio/pull/22936',
#     'diff_url': 'https://github.com/microsoft/azuredatastudio/pull/22936.diff',
#     'patch_url': 'https://github.com/microsoft/azuredatastudio/pull/22936.patch',
#     'issue_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/22936',
#     'number': 22936,
#     'state': 'open',
#     'locked': False,
#     'title': 'add securable settings',
#     'user': {'login': 'alanrenmsft',
#      'id': 13777222,
#      'node_id': 'MDQ6VXNlcjEzNzc3MjIy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/13777222?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alanrenmsft',
#      'html_url': 'https://github.com/alanrenmsft',
#      'followers_url': 'https://api.github.com/users/alanrenmsft/followers',
#      'following_url': 'https://api.github.com/users/alanrenmsft/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alanrenmsft/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alanrenmsft/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alanrenmsft/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alanrenmsft/orgs',
#      'repos_url': 'https://api.github.com/users/alanrenmsft/repos',
#      'events_url': 'https://api.github.com/users/alanrenmsft/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alanrenmsft/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'NOTE: the screenshots are based on test data. Hai is working on the STS changes.\r\n\r\nserver level objects:\r\n![server-level-securable](https://user-images.githubusercontent.com/13777222/235801025-c87a5417-a3a4-4206-9b75-57ddd5f08de4.gif)\r\n\r\n\r\ndatabase level objects:\r\n![db-level-securable](https://user-images.githubusercontent.com/13777222/235801042-a0993ba4-bd17-4a64-ab6d-48bd686461dd.gif)\r\n',
#     'created_at': '2023-05-02T22:45:31Z',
#     'updated_at': '2023-05-08T19:47:02Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '4c67f94fb3d62f4adacfbb8b7fd6582f2be61a06',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': True,
#     'commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936/commits',
#     'review_comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936/comments',
#     'review_comment_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/22936/comments',
#     'statuses_url': 'https://api.github.com/repos/microsoft/azuredatastudio/statuses/e15ef0d1056512c959f2241f248c3a845db31a09',
#     'head': {'label': 'microsoft:alanren/securable-settings',
#      'ref': 'alanren/securable-settings',
#      'sha': 'e15ef0d1056512c959f2241f248c3a845db31a09',
#      'user': {'login': 'microsoft',
#       'id': 6154722,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/microsoft',
#       'html_url': 'https://github.com/microsoft',
#       'followers_url': 'https://api.github.com/users/microsoft/followers',
#       'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#       'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#       'repos_url': 'https://api.github.com/users/microsoft/repos',
#       'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 109200851,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDkyMDA4NTE=',
#       'name': 'azuredatastudio',
#       'full_name': 'microsoft/azuredatastudio',
#       'private': False,
#       'owner': {'login': 'microsoft',
#        'id': 6154722,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/microsoft',
#        'html_url': 'https://github.com/microsoft',
#        'followers_url': 'https://api.github.com/users/microsoft/followers',
#        'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#        'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#        'repos_url': 'https://api.github.com/users/microsoft/repos',
#        'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/microsoft/azuredatastudio',
#       'description': 'Azure Data Studio is a data management and development tool with connectivity to popular cloud and on-premises databases. Azure Data Studio supports Windows, macOS, and Linux, with immediate capability to connect to Azure SQL and SQL Server. Browse the extension library for more database support options including MySQL, PostreSQL, and MongoDB.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/microsoft/azuredatastudio',
#       'forks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/forks',
#       'keys_url': 'https://api.github.com/repos/microsoft/azuredatastudio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/microsoft/azuredatastudio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/microsoft/azuredatastudio/teams',
#       'hooks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/events',
#       'assignees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/microsoft/azuredatastudio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/tags',
#       'blobs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/microsoft/azuredatastudio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/microsoft/azuredatastudio/languages',
#       'stargazers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscription',
#       'commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/microsoft/azuredatastudio/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/microsoft/azuredatastudio/merges',
#       'archive_url': 'https://api.github.com/repos/microsoft/azuredatastudio/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/microsoft/azuredatastudio/downloads',
#       'issues_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/microsoft/azuredatastudio/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/microsoft/azuredatastudio/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/microsoft/azuredatastudio/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/microsoft/azuredatastudio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/deployments',
#       'created_at': '2017-11-02T01:00:13Z',
#       'updated_at': '2023-05-08T03:06:09Z',
#       'pushed_at': '2023-05-08T19:26:22Z',
#       'git_url': 'git://github.com/microsoft/azuredatastudio.git',
#       'ssh_url': 'git@github.com:microsoft/azuredatastudio.git',
#       'clone_url': 'https://github.com/microsoft/azuredatastudio.git',
#       'svn_url': 'https://github.com/microsoft/azuredatastudio',
#       'homepage': 'https://learn.microsoft.com/sql/azure-data-studio',
#       'size': 625996,
#       'stargazers_count': 7125,
#       'watchers_count': 7125,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 860,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2108,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['azure',
#        'azure-data-studio',
#        'electron',
#        'microsoft',
#        'postgresql',
#        'sql',
#        'sql-server',
#        'typescript'],
#       'visibility': 'public',
#       'forks': 860,
#       'open_issues': 2108,
#       'watchers': 7125,
#       'default_branch': 'main'}},
#     'base': {'label': 'microsoft:main',
#      'ref': 'main',
#      'sha': '25bc14fb25579822a49f82e0cdbab02f2855b5d4',
#      'user': {'login': 'microsoft',
#       'id': 6154722,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/microsoft',
#       'html_url': 'https://github.com/microsoft',
#       'followers_url': 'https://api.github.com/users/microsoft/followers',
#       'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#       'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#       'repos_url': 'https://api.github.com/users/microsoft/repos',
#       'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 109200851,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDkyMDA4NTE=',
#       'name': 'azuredatastudio',
#       'full_name': 'microsoft/azuredatastudio',
#       'private': False,
#       'owner': {'login': 'microsoft',
#        'id': 6154722,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/microsoft',
#        'html_url': 'https://github.com/microsoft',
#        'followers_url': 'https://api.github.com/users/microsoft/followers',
#        'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#        'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#        'repos_url': 'https://api.github.com/users/microsoft/repos',
#        'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/microsoft/azuredatastudio',
#       'description': 'Azure Data Studio is a data management and development tool with connectivity to popular cloud and on-premises databases. Azure Data Studio supports Windows, macOS, and Linux, with immediate capability to connect to Azure SQL and SQL Server. Browse the extension library for more database support options including MySQL, PostreSQL, and MongoDB.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/microsoft/azuredatastudio',
#       'forks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/forks',
#       'keys_url': 'https://api.github.com/repos/microsoft/azuredatastudio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/microsoft/azuredatastudio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/microsoft/azuredatastudio/teams',
#       'hooks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/events',
#       'assignees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/microsoft/azuredatastudio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/tags',
#       'blobs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/microsoft/azuredatastudio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/microsoft/azuredatastudio/languages',
#       'stargazers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscription',
#       'commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/microsoft/azuredatastudio/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/microsoft/azuredatastudio/merges',
#       'archive_url': 'https://api.github.com/repos/microsoft/azuredatastudio/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/microsoft/azuredatastudio/downloads',
#       'issues_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/microsoft/azuredatastudio/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/microsoft/azuredatastudio/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/microsoft/azuredatastudio/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/microsoft/azuredatastudio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/deployments',
#       'created_at': '2017-11-02T01:00:13Z',
#       'updated_at': '2023-05-08T03:06:09Z',
#       'pushed_at': '2023-05-08T19:26:22Z',
#       'git_url': 'git://github.com/microsoft/azuredatastudio.git',
#       'ssh_url': 'git@github.com:microsoft/azuredatastudio.git',
#       'clone_url': 'https://github.com/microsoft/azuredatastudio.git',
#       'svn_url': 'https://github.com/microsoft/azuredatastudio',
#       'homepage': 'https://learn.microsoft.com/sql/azure-data-studio',
#       'size': 625996,
#       'stargazers_count': 7125,
#       'watchers_count': 7125,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 860,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2108,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['azure',
#        'azure-data-studio',
#        'electron',
#        'microsoft',
#        'postgresql',
#        'sql',
#        'sql-server',
#        'typescript'],
#       'visibility': 'public',
#       'forks': 860,
#       'open_issues': 2108,
#       'watchers': 7125,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936'},
#      'html': {'href': 'https://github.com/microsoft/azuredatastudio/pull/22936'},
#      'issue': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/22936'},
#      'comments': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/22936/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/statuses/e15ef0d1056512c959f2241f248c3a845db31a09'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-05-08T19:47:02Z',
#   'org': {'id': 6154722,
#    'login': 'microsoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/microsoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?'}},
#  {'id': '28927456040',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 21186993,
#    'login': 'caohai',
#    'display_login': 'caohai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caohai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21186993?'},
#   'repo': {'id': 109200851,
#    'name': 'microsoft/azuredatastudio',
#    'url': 'https://api.github.com/repos/microsoft/azuredatastudio'},
#   'payload': {'action': 'created',
#    'review': {'id': 1417405633,
#     'node_id': 'PRR_kwDOBoJF085Ue-TB',
#     'user': {'login': 'caohai',
#      'id': 21186993,
#      'node_id': 'MDQ6VXNlcjIxMTg2OTkz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/21186993?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/caohai',
#      'html_url': 'https://github.com/caohai',
#      'followers_url': 'https://api.github.com/users/caohai/followers',
#      'following_url': 'https://api.github.com/users/caohai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/caohai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/caohai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/caohai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/caohai/orgs',
#      'repos_url': 'https://api.github.com/users/caohai/repos',
#      'events_url': 'https://api.github.com/users/caohai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/caohai/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'commit_id': 'e15ef0d1056512c959f2241f248c3a845db31a09',
#     'submitted_at': '2023-05-08T19:47:02Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/microsoft/azuredatastudio/pull/22936#pullrequestreview-1417405633',
#     'pull_request_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936',
#     'author_association': 'MEMBER',
#     '_links': {'html': {'href': 'https://github.com/microsoft/azuredatastudio/pull/22936#pullrequestreview-1417405633'},
#      'pull_request': {'href': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936',
#     'id': 1335918835,
#     'node_id': 'PR_kwDOBoJF085PoIDz',
#     'html_url': 'https://github.com/microsoft/azuredatastudio/pull/22936',
#     'diff_url': 'https://github.com/microsoft/azuredatastudio/pull/22936.diff',
#     'patch_url': 'https://github.com/microsoft/azuredatastudio/pull/22936.patch',
#     'issue_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/22936',
#     'number': 22936,
#     'state': 'open',
#     'locked': False,
#     'title': 'add securable settings',
#     'user': {'login': 'alanrenmsft',
#      'id': 13777222,
#      'node_id': 'MDQ6VXNlcjEzNzc3MjIy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/13777222?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alanrenmsft',
#      'html_url': 'https://github.com/alanrenmsft',
#      'followers_url': 'https://api.github.com/users/alanrenmsft/followers',
#      'following_url': 'https://api.github.com/users/alanrenmsft/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alanrenmsft/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alanrenmsft/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alanrenmsft/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alanrenmsft/orgs',
#      'repos_url': 'https://api.github.com/users/alanrenmsft/repos',
#      'events_url': 'https://api.github.com/users/alanrenmsft/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alanrenmsft/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'NOTE: the screenshots are based on test data. Hai is working on the STS changes.\r\n\r\nserver level objects:\r\n![server-level-securable](https://user-images.githubusercontent.com/13777222/235801025-c87a5417-a3a4-4206-9b75-57ddd5f08de4.gif)\r\n\r\n\r\ndatabase level objects:\r\n![db-level-securable](https://user-images.githubusercontent.com/13777222/235801042-a0993ba4-bd17-4a64-ab6d-48bd686461dd.gif)\r\n',
#     'created_at': '2023-05-02T22:45:31Z',
#     'updated_at': '2023-05-08T19:47:02Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '4c67f94fb3d62f4adacfbb8b7fd6582f2be61a06',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': True,
#     'commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936/commits',
#     'review_comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/22936/comments',
#     'review_comment_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/22936/comments',
#     'statuses_url': 'https://api.github.com/repos/microsoft/azuredatastudio/statuses/e15ef0d1056512c959f2241f248c3a845db31a09',
#     'head': {'label': 'microsoft:alanren/securable-settings',
#      'ref': 'alanren/securable-settings',
#      'sha': 'e15ef0d1056512c959f2241f248c3a845db31a09',
#      'user': {'login': 'microsoft',
#       'id': 6154722,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/microsoft',
#       'html_url': 'https://github.com/microsoft',
#       'followers_url': 'https://api.github.com/users/microsoft/followers',
#       'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#       'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#       'repos_url': 'https://api.github.com/users/microsoft/repos',
#       'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 109200851,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDkyMDA4NTE=',
#       'name': 'azuredatastudio',
#       'full_name': 'microsoft/azuredatastudio',
#       'private': False,
#       'owner': {'login': 'microsoft',
#        'id': 6154722,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/microsoft',
#        'html_url': 'https://github.com/microsoft',
#        'followers_url': 'https://api.github.com/users/microsoft/followers',
#        'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#        'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#        'repos_url': 'https://api.github.com/users/microsoft/repos',
#        'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/microsoft/azuredatastudio',
#       'description': 'Azure Data Studio is a data management and development tool with connectivity to popular cloud and on-premises databases. Azure Data Studio supports Windows, macOS, and Linux, with immediate capability to connect to Azure SQL and SQL Server. Browse the extension library for more database support options including MySQL, PostreSQL, and MongoDB.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/microsoft/azuredatastudio',
#       'forks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/forks',
#       'keys_url': 'https://api.github.com/repos/microsoft/azuredatastudio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/microsoft/azuredatastudio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/microsoft/azuredatastudio/teams',
#       'hooks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/events',
#       'assignees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/microsoft/azuredatastudio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/tags',
#       'blobs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/microsoft/azuredatastudio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/microsoft/azuredatastudio/languages',
#       'stargazers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscription',
#       'commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/microsoft/azuredatastudio/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/microsoft/azuredatastudio/merges',
#       'archive_url': 'https://api.github.com/repos/microsoft/azuredatastudio/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/microsoft/azuredatastudio/downloads',
#       'issues_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/microsoft/azuredatastudio/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/microsoft/azuredatastudio/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/microsoft/azuredatastudio/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/microsoft/azuredatastudio/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/microsoft/azuredatastudio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/deployments',
#       'created_at': '2017-11-02T01:00:13Z',
#       'updated_at': '2023-05-08T03:06:09Z',
#       'pushed_at': '2023-05-08T19:26:22Z',
#       'git_url': 'git://github.com/microsoft/azuredatastudio.git',
#       'ssh_url': 'git@github.com:microsoft/azuredatastudio.git',
#       'clone_url': 'https://github.com/microsoft/azuredatastudio.git',
#       'svn_url': 'https://github.com/microsoft/azuredatastudio',
#       'homepage': 'https://learn.microsoft.com/sql/azure-data-studio',
#       'size': 625996,
#       'stargazers_count': 7125,
#       'watchers_count': 7125,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 860,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2108,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['azure',
#        'azure-data-studio',
#        'electron',
#        'microsoft',
#        'postgresql',
#        'sql',
#        'sql-server',
#        'typescript'],
#       'visibility': 'public',
#       'forks': 860,
#       'open_issues': 2108,
#       'watchers': 7125,
#       'default_branch': 'main'}},
#     'base': {'label': 'microsoft:main',
#      'ref': 'main',
#      'sha': '25bc14fb25579822a49f82e0cdbab02f2855b5d4',
#      'user': {'login': 'microsoft',
#       'id': 6154722,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/microsoft',
#       'html_url': 'https://github.com/microsoft',
#       'followers_url': 'https://api.github.com/users/microsoft/followers',
#       'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#       'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#       'repos_url': 'https://api.github.com/users/microsoft/repos',
#       'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 109200851,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDkyMDA4NTE=',
#       'name': 'azuredatastudio',
#       'full_name': 'microsoft/azuredatastudio',
#       'private': False,
#       'owner': {'login': 'microsoft',
#        'id': 6154722,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/microsoft',
#        'html_url': 'https://github.com/microsoft',
#        'followers_url': 'https://api.github.com/users/microsoft/followers',
#        'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#        'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#        'repos_url': 'https://api.github.com/users/microsoft/repos',
#        'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/microsoft/azuredatastudio',
#       'description': 'Azure Data Studio is a data management and development tool with connectivity to popular cloud and on-premises databases. Azure Data Studio supports Windows, macOS, and Linux, with immediate capability to connect to Azure SQL and SQL Server. Browse the extension library for more database support options including MySQL, PostreSQL, and MongoDB.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/microsoft/azuredatastudio',
#       'forks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/forks',
#       'keys_url': 'https://api.github.com/repos/microsoft/azuredatastudio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/microsoft/azuredatastudio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/microsoft/azuredatastudio/teams',
#       'hooks_url': 'https://api.github.com/repos/microsoft/azuredatastudio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/microsoft/azuredatastudio/events',
#       'assignees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/microsoft/azuredatastudio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/tags',
#       'blobs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/microsoft/azuredatastudio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/microsoft/azuredatastudio/languages',
#       'stargazers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/microsoft/azuredatastudio/subscription',
#       'commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/microsoft/azuredatastudio/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/microsoft/azuredatastudio/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/microsoft/azuredatastudio/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/microsoft/azuredatastudio/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/microsoft/azuredatastudio/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/microsoft/azuredatastudio/merges',
#       'archive_url': 'https://api.github.com/repos/microsoft/azuredatastudio/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/microsoft/azuredatastudio/downloads',
# ...
#       'url': 'https://api.github.com/users/encoreee',
#       'html_url': 'https://github.com/encoreee',
#       'followers_url': 'https://api.github.com/users/encoreee/followers',
#       'following_url': 'https://api.github.com/users/encoreee/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/encoreee/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/encoreee/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/encoreee/subscriptions',
#       'organizations_url': 'https://api.github.com/users/encoreee/orgs',
#       'repos_url': 'https://api.github.com/users/encoreee/repos',
#       'events_url': 'https://api.github.com/users/encoreee/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/encoreee/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 628996161,
#       'node_id': 'R_kgDOJX24QQ',
#       'name': 'GameDevPractikum',
#       'full_name': 'encoreee/GameDevPractikum',
#       'private': False,
#       'owner': {'login': 'encoreee',
#        'id': 44232406,
#        'node_id': 'MDQ6VXNlcjQ0MjMyNDA2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/44232406?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/encoreee',
#        'html_url': 'https://github.com/encoreee',
#        'followers_url': 'https://api.github.com/users/encoreee/followers',
#        'following_url': 'https://api.github.com/users/encoreee/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/encoreee/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/encoreee/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/encoreee/subscriptions',
#        'organizations_url': 'https://api.github.com/users/encoreee/orgs',
#        'repos_url': 'https://api.github.com/users/encoreee/repos',
#        'events_url': 'https://api.github.com/users/encoreee/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/encoreee/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/encoreee/GameDevPractikum',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/encoreee/GameDevPractikum',
#       'forks_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/forks',
#       'keys_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/teams',
#       'hooks_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/hooks',
#       'issue_events_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/events',
#       'assignees_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/tags',
#       'blobs_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/languages',
#       'stargazers_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/stargazers',
#       'contributors_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/contributors',
#       'subscribers_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/subscribers',
#       'subscription_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/subscription',
#       'commits_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/merges',
#       'archive_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/downloads',
#       'issues_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/deployments',
#       'created_at': '2023-04-17T12:10:46Z',
#       'updated_at': '2023-04-17T12:10:54Z',
#       'pushed_at': '2023-05-08T19:45:26Z',
#       'git_url': 'git://github.com/encoreee/GameDevPractikum.git',
#       'ssh_url': 'git@github.com:encoreee/GameDevPractikum.git',
#       'clone_url': 'https://github.com/encoreee/GameDevPractikum.git',
#       'svn_url': 'https://github.com/encoreee/GameDevPractikum',
#       'homepage': None,
#       'size': 630,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'encoreee:sprint_1',
#      'ref': 'sprint_1',
#      'sha': 'd0fe93a12b2b93d3911ae1be7d3697643d47618a',
#      'user': {'login': 'encoreee',
#       'id': 44232406,
#       'node_id': 'MDQ6VXNlcjQ0MjMyNDA2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/44232406?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/encoreee',
#       'html_url': 'https://github.com/encoreee',
#       'followers_url': 'https://api.github.com/users/encoreee/followers',
#       'following_url': 'https://api.github.com/users/encoreee/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/encoreee/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/encoreee/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/encoreee/subscriptions',
#       'organizations_url': 'https://api.github.com/users/encoreee/orgs',
#       'repos_url': 'https://api.github.com/users/encoreee/repos',
#       'events_url': 'https://api.github.com/users/encoreee/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/encoreee/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 628996161,
#       'node_id': 'R_kgDOJX24QQ',
#       'name': 'GameDevPractikum',
#       'full_name': 'encoreee/GameDevPractikum',
#       'private': False,
#       'owner': {'login': 'encoreee',
#        'id': 44232406,
#        'node_id': 'MDQ6VXNlcjQ0MjMyNDA2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/44232406?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/encoreee',
#        'html_url': 'https://github.com/encoreee',
#        'followers_url': 'https://api.github.com/users/encoreee/followers',
#        'following_url': 'https://api.github.com/users/encoreee/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/encoreee/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/encoreee/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/encoreee/subscriptions',
#        'organizations_url': 'https://api.github.com/users/encoreee/orgs',
#        'repos_url': 'https://api.github.com/users/encoreee/repos',
#        'events_url': 'https://api.github.com/users/encoreee/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/encoreee/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/encoreee/GameDevPractikum',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/encoreee/GameDevPractikum',
#       'forks_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/forks',
#       'keys_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/teams',
#       'hooks_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/hooks',
#       'issue_events_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/events',
#       'assignees_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/tags',
#       'blobs_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/languages',
#       'stargazers_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/stargazers',
#       'contributors_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/contributors',
#       'subscribers_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/subscribers',
#       'subscription_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/subscription',
#       'commits_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/merges',
#       'archive_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/downloads',
#       'issues_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/encoreee/GameDevPractikum/deployments',
#       'created_at': '2023-04-17T12:10:46Z',
#       'updated_at': '2023-04-17T12:10:54Z',
#       'pushed_at': '2023-05-08T19:45:26Z',
#       'git_url': 'git://github.com/encoreee/GameDevPractikum.git',
#       'ssh_url': 'git@github.com:encoreee/GameDevPractikum.git',
#       'clone_url': 'https://github.com/encoreee/GameDevPractikum.git',
#       'svn_url': 'https://github.com/encoreee/GameDevPractikum',
#       'homepage': None,
#       'size': 630,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/encoreee/GameDevPractikum/pulls/15'},
#      'html': {'href': 'https://github.com/encoreee/GameDevPractikum/pull/15'},
#      'issue': {'href': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues/15'},
#      'comments': {'href': 'https://api.github.com/repos/encoreee/GameDevPractikum/issues/15/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/encoreee/GameDevPractikum/pulls/15/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/encoreee/GameDevPractikum/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/encoreee/GameDevPractikum/pulls/15/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/encoreee/GameDevPractikum/statuses/3fcaaa4896ed80274560a5e1ff690271d1e863e8'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-05-08T19:47:03Z'},
#  {'id': '28927455975',
#   'type': 'PushEvent',
#   'actor': {'id': 131870404,
#    'login': 'veronaRub',
#    'display_login': 'veronaRub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/veronaRub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/131870404?'},
#   'repo': {'id': 636350760,
#    'name': 'veronaRub/Lesson_2',
#    'url': 'https://api.github.com/repos/veronaRub/Lesson_2'},
#   'payload': {'repository_id': 636350760,
#    'push_id': 13565005627,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e65bc039cd78f3e53e94f6db0c672ca11d1e3e5d',
#    'before': '76522006361ec49079ece9746e3e6003ee62372b',
#    'commits': [{'sha': 'e65bc039cd78f3e53e94f6db0c672ca11d1e3e5d',
#      'author': {'email': 'rublyuk.v@gmail.com', 'name': 'veronaRub'},
#      'message': 'fiirst commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/veronaRub/Lesson_2/commits/e65bc039cd78f3e53e94f6db0c672ca11d1e3e5d'}]},
#   'public': True,
#   'created_at': '2023-05-08T19:47:03Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2023-05-03T23:39:23Z',
#   'pushed_at': '2023-03-08T20:02:27Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 11,
#   'stargazers_count': 9,
#   'watchers_count': 9,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 231,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 231,
#   'open_issues': 1,
#   'watchers': 9,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2023-05-03T03:32:13Z',
#   'pushed_at': '2023-04-03T15:56:54Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 137,
#   'stargazers_count': 47,
#   'watchers_count': 47,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 1,
#   'watchers': 47,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2022-10-02T03:02:36Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 62,
#   'watchers_count': 62,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 62,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2023-04-19T06:50:22Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1131,
#   'watchers_count': 1131,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1065,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1065,
#   'open_issues': 11,
#   'watchers': 1131,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2023-01-13T18:26:35Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 4,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2023-04-05T09:44:25Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 91,
#   'watchers_count': 91,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 71,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 71,
#   'open_issues': 14,
#   'watchers': 91,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2023-03-09T04:19:54Z',
#   'pushed_at': '2023-04-10T09:29:53Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2337,
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 9,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 9,
#   'open_issues': 0,
#   'watchers': 14,
#   'default_branch': 'main'},
#  {'id': 397426400,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTc0MjY0MDA=',
#   'name': 'amazon-frustration-free-setup-certification-tool',
#   'full_name': 'amzn/amazon-frustration-free-setup-certification-tool',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-frustration-free-setup-certification-tool',
#   'description': 'Python-based automation scripts which can run device provisioning performance test',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/deployments',
#   'created_at': '2021-08-18T00:30:56Z',
#   'updated_at': '2022-11-27T13:14:30Z',
#   'pushed_at': '2023-05-05T17:14:41Z',
#   'git_url': 'git://github.com/amzn/amazon-frustration-free-setup-certification-tool.git',
#   'ssh_url': 'git@github.com:amzn/amazon-frustration-free-setup-certification-tool.git',
# ...
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/deployments',
#   'created_at': '2015-01-23T23:00:34Z',
#   'updated_at': '2022-11-27T13:10:47Z',
#   'pushed_at': '2023-04-10T09:50:19Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-python.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-python.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-python.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-python',
#   'homepage': '',
#   'size': 83,
#   'stargazers_count': 49,
#   'watchers_count': 49,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 38,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 8,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 38,
#   'open_issues': 8,
#   'watchers': 49,
#   'default_branch': 'master'},
#  {'id': 29876251,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTg3NjI1MQ==',
#   'name': 'amazon-pay-sdk-ruby',
#   'full_name': 'amzn/amazon-pay-sdk-ruby',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-ruby',
#   'description': 'Amazon Pay Ruby SDK ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-ruby/deployments',
#   'created_at': '2015-01-26T18:56:59Z',
#   'updated_at': '2023-03-30T07:06:13Z',
#   'pushed_at': '2023-02-06T15:36:52Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-ruby.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-ruby.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-ruby.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-ruby',
#   'homepage': 'https://pay.amazon.com/developer',
#   'size': 92,
#   'stargazers_count': 57,
#   'watchers_count': 57,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 8,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 8,
#   'watchers': 57,
#   'default_branch': 'master'},
#  {'id': 33279165,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzI3OTE2NQ==',
#   'name': 'amazon-pay-sdk-samples',
#   'full_name': 'amzn/amazon-pay-sdk-samples',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-samples',
#   'description': 'Amazon Pay SDK Sample Code',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-samples/deployments',
#   'created_at': '2015-04-01T23:52:35Z',
#   'updated_at': '2022-10-28T07:26:49Z',
#   'pushed_at': '2023-04-10T09:51:00Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-samples.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-samples.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-samples.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-samples',
#   'homepage': '',
#   'size': 4573,
#   'stargazers_count': 37,
#   'watchers_count': 37,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 35,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 10,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 35,
#   'open_issues': 10,
#   'watchers': 37,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
access_token = 'seu_token'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# ### Paginando os repositórios

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2023-05-03T23:39:23Z',
#    'pushed_at': '2023-03-08T20:02:27Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 11,
#    'stargazers_count': 9,
#    'watchers_count': 9,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 231,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 231,
#    'open_issues': 1,
#    'watchers': 9,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2023-05-03T03:32:13Z',
#    'pushed_at': '2023-04-03T15:56:54Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 137,
#    'stargazers_count': 47,
#    'watchers_count': 47,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 25,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 25,
#    'open_issues': 1,
#    'watchers': 47,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2022-10-02T03:02:36Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 62,
#    'watchers_count': 62,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 25,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 25,
#    'open_issues': 4,
#    'watchers': 62,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2023-04-19T06:50:22Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1131,
#    'watchers_count': 1131,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1065,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1065,
#    'open_issues': 11,
#    'watchers': 1131,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2023-01-13T18:26:35Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 4,
#    'watchers_count': 4,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 2,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 2,
#    'open_issues': 0,
#    'watchers': 4,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2023-04-05T09:44:25Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 91,
#    'watchers_count': 91,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 71,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 71,
#    'open_issues': 14,
#    'watchers': 91,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#    'created_at': '2021-11-18T04:37:55Z',
#    'updated_at': '2023-03-09T04:19:54Z',
#    'pushed_at': '2023-04-10T09:29:53Z',
#    'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#    'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#    'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#    'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'homepage': '',
#    'size': 2337,
#    'stargazers_count': 14,
#    'watchers_count': 14,
#    'language': 'Java',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 9,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 9,
#    'open_issues': 0,
#    'watchers': 14,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 397426400,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTc0MjY0MDA=',
#    'name': 'amazon-frustration-free-setup-certification-tool',
#    'full_name': 'amzn/amazon-frustration-free-setup-certification-tool',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-frustration-free-setup-certification-tool',
#    'description': 'Python-based automation scripts which can run device provisioning performance test',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/compare/{base}...{head}',
# ...
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/deployments',
#    'created_at': '2019-10-04T18:00:25Z',
#    'updated_at': '2022-11-27T13:16:03Z',
#    'pushed_at': '2022-05-03T10:06:27Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-s7comm.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-s7comm.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-s7comm.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-s7comm',
#    'homepage': None,
#    'size': 35,
#    'stargazers_count': 32,
#    'watchers_count': 32,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 13,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 13,
#    'open_issues': 2,
#    'watchers': 32,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212874433,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzQ0MzM=',
#    'name': 'zeek-plugin-tds',
#    'full_name': 'amzn/zeek-plugin-tds',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Tabular Data Stream (TDS) protocol',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-tds',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/deployments',
#    'created_at': '2019-10-04T18:01:45Z',
#    'updated_at': '2022-08-11T01:53:45Z',
#    'pushed_at': '2023-04-25T22:40:08Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-tds.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-tds.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-tds.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'homepage': '',
#    'size': 25,
#    'stargazers_count': 20,
#    'watchers_count': 20,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 9,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 9,
#    'open_issues': 1,
#    'watchers': 20,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 361620746,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2MjA3NDY=',
#    'name': 'zero-shot-rlhr',
#    'full_name': 'amzn/zero-shot-rlhr',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zero-shot-rlhr',
#    'forks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/deployments',
#    'created_at': '2021-04-26T04:49:11Z',
#    'updated_at': '2023-03-08T11:29:36Z',
#    'pushed_at': '2021-04-26T05:39:00Z',
#    'git_url': 'git://github.com/amzn/zero-shot-rlhr.git',
#    'ssh_url': 'git@github.com:amzn/zero-shot-rlhr.git',
#    'clone_url': 'https://github.com/amzn/zero-shot-rlhr.git',
#    'svn_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'homepage': None,
#    'size': 119,
#    'stargazers_count': 42,
#    'watchers_count': 42,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 13,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 13,
#    'open_issues': 1,
#    'watchers': 42,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2023-05-03T23:39:23Z',
#    'pushed_at': '2023-03-08T20:02:27Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 11,
#    'stargazers_count': 9,
#    'watchers_count': 9,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 231,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 231,
#    'open_issues': 1,
#    'watchers': 9,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2023-05-03T03:32:13Z',
#    'pushed_at': '2023-04-03T15:56:54Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 137,
#    'stargazers_count': 47,
#    'watchers_count': 47,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 25,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 25,
#    'open_issues': 1,
#    'watchers': 47,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2022-10-02T03:02:36Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 62,
#    'watchers_count': 62,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 25,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 25,
#    'open_issues': 4,
#    'watchers': 62,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2023-04-19T06:50:22Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1131,
#    'watchers_count': 1131,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1065,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1065,
#    'open_issues': 11,
#    'watchers': 1131,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2023-01-13T18:26:35Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 4,
#    'watchers_count': 4,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 2,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 2,
#    'open_issues': 0,
#    'watchers': 4,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2023-04-05T09:44:25Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 91,
#    'watchers_count': 91,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 71,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 71,
#    'open_issues': 14,
#    'watchers': 91,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#    'created_at': '2021-11-18T04:37:55Z',
#    'updated_at': '2023-03-09T04:19:54Z',
#    'pushed_at': '2023-04-10T09:29:53Z',
#    'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#    'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#    'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#    'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'homepage': '',
#    'size': 2337,
#    'stargazers_count': 14,
#    'watchers_count': 14,
#    'language': 'Java',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 9,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 9,
#    'open_issues': 0,
#    'watchers': 14,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 397426400,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTc0MjY0MDA=',
#    'name': 'amazon-frustration-free-setup-certification-tool',
#    'full_name': 'amzn/amazon-frustration-free-setup-certification-tool',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-frustration-free-setup-certification-tool',
#    'description': 'Python-based automation scripts which can run device provisioning performance test',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-frustration-free-setup-certification-tool/compare/{base}...{head}',
# ...
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/deployments',
#    'created_at': '2019-10-04T18:00:25Z',
#    'updated_at': '2022-11-27T13:16:03Z',
#    'pushed_at': '2022-05-03T10:06:27Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-s7comm.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-s7comm.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-s7comm.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-s7comm',
#    'homepage': None,
#    'size': 35,
#    'stargazers_count': 32,
#    'watchers_count': 32,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 13,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 13,
#    'open_issues': 2,
#    'watchers': 32,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212874433,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzQ0MzM=',
#    'name': 'zeek-plugin-tds',
#    'full_name': 'amzn/zeek-plugin-tds',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Tabular Data Stream (TDS) protocol',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-tds',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/deployments',
#    'created_at': '2019-10-04T18:01:45Z',
#    'updated_at': '2022-08-11T01:53:45Z',
#    'pushed_at': '2023-04-25T22:40:08Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-tds.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-tds.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-tds.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'homepage': '',
#    'size': 25,
#    'stargazers_count': 20,
#    'watchers_count': 20,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 9,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 9,
#    'open_issues': 1,
#    'watchers': 20,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 361620746,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2MjA3NDY=',
#    'name': 'zero-shot-rlhr',
#    'full_name': 'amzn/zero-shot-rlhr',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zero-shot-rlhr',
#    'forks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/deployments',
#    'created_at': '2021-04-26T04:49:11Z',
#    'updated_at': '2023-03-08T11:29:36Z',
#    'pushed_at': '2021-04-26T05:39:00Z',
#    'git_url': 'git://github.com/amzn/zero-shot-rlhr.git',
#    'ssh_url': 'git@github.com:amzn/zero-shot-rlhr.git',
#    'clone_url': 'https://github.com/amzn/zero-shot-rlhr.git',
#    'svn_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'homepage': None,
#    'size': 119,
#    'stargazers_count': 42,
#    'watchers_count': 42,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 13,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 13,
#    'open_issues': 1,
#    'watchers': 42,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
repos_list[0][2]['name']
# Out:
# 'alexa-coho'

# %%
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs',
#  'amazon-hub-counter-api-samples']

# %%
len(repos_name)
# Out:
# 133

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 133

# %%
repos_language
# Out:
# [None,
#  None,
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  'Kotlin',
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Java',
#  'Java',
#  'Java',
#  'C#',
#  'C#',
#  'JavaScript',
#  'JavaScript',
#  'Go',
#  'Java',
#  'TypeScript',
#  'Python',
#  'C++',
#  None,
#  'Python',
#  'C#',
#  'HTML',
#  None,
#  'PHP',
#  'PHP',
#  'Java',
#  'Python',
#  'Scala',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Swift',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Ruby',
#  'Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'Python',
#  'C++',
#  'Java',
#  'HTML',
#  'Java',
#  'Python',
#  'Swift',
#  'JavaScript',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Python',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'Python',
#  'JavaScript',
#  'Python',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Python']

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['language'] = repos_language

# %%
dados_amz
# Out:
#                                        repository_name    language
# 0                                              .github        None
# 1                              ads-advanced-tools-docs        None
# 2                                           alexa-coho  JavaScript
# 3                                  alexa-skills-kit-js        None
# 4    amazon-ads-advertiser-audience-normalization-s...      Python
# ..                                                 ...         ...
# 128                                   zeek-plugin-enip        Zeek
# 129                               zeek-plugin-profinet        Zeek
# 130                                 zeek-plugin-s7comm        Zeek
# 131                                    zeek-plugin-tds        Zeek
# 132                                     zero-shot-rlhr      Python
#
# [133 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# ### Formato do arquivo

# %%
import base64

# %%
with open('amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)

# %% [markdown]
# ### Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'millenagena'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/millenagena/linguagens-utilizadas/contents/amazon.csv'

# %%
data = {
    'message': 'Adicionando um novo arquivo',
    'content': encoded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201
